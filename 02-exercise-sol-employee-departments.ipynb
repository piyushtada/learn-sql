# %%
import os
import glob
import psycopg2
import pandas as pd

# %%
# you need to below command to start the sql sever before you can do anything
! pg_ctl -D /usr/local/var/postgres start
# Out:
# pg_ctl: another server might be running; trying to start server anyway
# waiting for server to start....2021-07-04 17:00:00.976 IST [39060] FATAL:  lock file "postmaster.pid" already exists
# 2021-07-04 17:00:00.976 IST [39060] HINT:  Is another postmaster (PID 32148) running in data directory "/usr/local/var/postgres"?
#  stopped waiting
# pg_ctl: could not start server
# Examine the log output.

# %%
def connect_database(dbName):
    """
    The function to create database

    Returns:
        cur  : Use the connection to get a cursor that will be used to execute queries.
        conn : The connection towards current connecting database.
    """

    # connect to default database
    conn = psycopg2.connect("host=127.0.0.1 dbname={} user=piyush2017 password=password".format(dbName))
    conn.set_session(autocommit=True)
    cur = conn.cursor()

    return cur, conn

# %%
cur, conn = connect_database('interviews')

# %%
# you need to run the below command to make it possible to run sql commands directly in a jupeter notebook cell
# %load_ext sql

# %%
# %sql postgresql://piyush2017:password@127.0.0.1/interviews

# %%
# %%sql
#
# SELECT * FROM DataSubordinates;
# Out:
#  * postgresql://piyush2017:***@127.0.0.1/interviews
# 100 rows affected.
# [(101, 'Brock Cherry', 1990, 'F', 3, 179),
#  (102, 'Calvin Anthony', 1963, 'F', 2, 192),
#  (103, 'Tad Hughes', 1980, 'F', 4, 177),
#  (104, 'Odysseus Norton', 1982, 'F', 5, 181),
#  (105, 'Vernon Randolph', 1991, 'M', 1, 184),
#  (106, 'Colton Riggs', 1965, 'M', 4, 190),
#  (107, 'Brock Key', 1938, 'F', 2, 178),
#  (108, 'Kasimir Larsen', 1958, 'F', 6, 185),
#  (109, 'Barrett Hebert', 1950, 'M', 4, 180),
#  (110, 'Wyatt Nicholson', 1983, 'F', 2, 188),
#  (111, 'Mufutau Mitchell', 1935, 'M', 2, 156),
#  (112, 'Lawrence Cote', 1932, 'M', 2, 170),
#  (113, 'Timon Mcmahon', 1953, 'M', 6, 177),
#  (114, 'Malcolm Oconnor', 1975, 'M', 3, 184),
#  (115, 'Odysseus Delgado', 1940, 'M', 6, 192),
#  (116, 'Igor Morgan', 1994, 'M', 2, 164),
#  (117, 'Christopher Jordan', 1947, 'M', 3, 172),
#  (118, 'Nolan Reese', 1995, 'F', 5, 171),
#  (119, 'Garth Gomez', 1942, 'F', 4, 182),
#  (120, 'Buckminster Estrada', 1960, 'F', 3, 171),
#  (121, 'Gregory Morin', 1926, 'F', 1, 195),
#  (122, 'Troy Chandler', 1939, 'F', 3, 175),
#  (123, 'Chester Atkins', 1938, 'F', 6, 194),
#  (124, 'Felix Frye', 1910, 'F', 1, 154),
#  (125, 'Wallace Oliver', 1933, 'M', 2, 172),
#  (126, 'Hakeem Ferrell', 1950, 'M', 5, 153),
#  (127, 'Paki Phillips', 1949, 'F', 5, 178),
#  (128, 'Shad Whitfield', 2000, 'M', 2, 159),
#  (129, 'Wylie Cannon', 1961, 'F', 5, 187),
#  (130, 'Elvis Buchanan', 1915, 'F', 5, 167),
#  (131, 'Brody Mccarty', 1966, 'F', 2, 197),
#  (132, 'Brett Bentley', 1908, 'M', 4, 200),
#  (133, 'Xanthus Fox', 1931, 'M', 5, 160),
#  (134, 'William Dejesus', 1969, 'M', 1, 176),
#  (135, 'Phillip Tillman', 1927, 'F', 6, 167),
#  (136, 'Kato Martinez', 1993, 'F', 4, 150),
#  (137, 'Nicholas Daugherty', 1986, 'M', 1, 183),
#  (138, 'Howard Shepard', 1910, 'M', 1, 197),
#  (139, 'Jackson Sellers', 1903, 'M', 3, 190),
#  (140, 'Jack Ramirez', 1960, 'F', 4, 171),
#  (141, 'Wyatt House', 1990, 'F', 1, 186),
#  (142, 'Gavin Benton', 1996, 'M', 3, 179),
#  (143, 'Xanthus Holman', 1943, 'M', 1, 189),
#  (144, 'Price Chavez', 1928, 'M', 1, 193),
#  (145, 'Steven Sawyer', 1981, 'F', 4, 160),
#  (146, 'Tate Hopper', 1966, 'M', 5, 158),
#  (147, 'Henry Lane', 1905, 'M', 6, 191),
#  (148, 'Dane Medina', 1940, 'M', 1, 187),
#  (149, 'Joshua Fernandez', 1990, 'M', 6, 172),
#  (150, 'Harlan Rivas', 1922, 'F', 5, 183),
#  (151, 'Wade Berger', 1961, 'F', 5, 193),
#  (152, 'Louis Townsend', 1912, 'M', 3, 152),
#  (153, 'Marvin Harrell', 1957, 'F', 3, 159),
#  (154, 'Richard Carrillo', 1930, 'M', 6, 176),
#  (155, 'Norman Booth', 1952, 'M', 5, 198),
#  (156, 'Ray Reid', 1933, 'F', 5, 184),
#  (157, 'Xanthus Ortega', 1943, 'F', 1, 175),
#  (158, 'Jack Cooper', 1904, 'F', 2, 192),
#  (159, 'Peter Pearson', 1944, 'M', 5, 174),
#  (160, 'Neville Blanchard', 1952, 'M', 5, 159),
#  (161, 'Cain Johnston', 1987, 'F', 6, 155),
#  (162, 'Tiger Dennis', 1970, 'M', 1, 150),
#  (163, 'Marshall Rice', 1912, 'F', 6, 191),
#  (164, 'Macaulay Huffman', 1908, 'M', 4, 188),
#  (165, 'Hamilton Porter', 1969, 'F', 2, 189),
#  (166, 'Joshua Craig', 1903, 'F', 4, 150),
#  (167, 'Colby Glass', 2008, 'M', 4, 158),
#  (168, 'Walker Wiggins', 1916, 'F', 1, 193),
#  (169, 'Garrison Bauer', 1949, 'M', 3, 184),
#  (170, 'Clark Meadows', 1926, 'M', 6, 171),
#  (171, 'Rudyard Hendrix', 1951, 'F', 1, 165),
#  (172, 'Bevis Maxwell', 1971, 'M', 3, 184),
#  (173, 'Ali Robinson', 1988, 'F', 3, 179),
#  (174, 'Dominic Faulkner', 1956, 'M', 3, 196),
#  (175, 'Wyatt Vance', 1990, 'F', 1, 159),
#  (176, 'Kenneth Snyder', 1983, 'M', 6, 186),
#  (177, 'Jerry Donovan', 1914, 'F', 5, 159),
#  (178, 'Dante Jensen', 1916, 'F', 4, 150),
#  (179, 'Hop White', 1979, 'F', 5, 189),
#  (180, 'Conan Allison', 1927, 'F', 1, 168),
#  (181, 'Hashim Mcclure', 1999, 'M', 5, 191),
#  (182, 'Leroy Buck', 2001, 'F', 6, 165),
#  (183, 'Leo Austin', 1988, 'M', 4, 187),
#  (184, 'Hop Bender', 1936, 'F', 2, 172),
#  (185, 'Amir Blackburn', 1984, 'F', 6, 153),
#  (186, 'Elmo Mooney', 1946, 'M', 6, 167),
#  (187, 'Driscoll Benton', 1979, 'F', 6, 154),
#  (188, 'Chase Battle', 1901, 'F', 4, 154),
#  (189, 'Asher Jarvis', 1979, 'F', 6, 197),
#  (190, 'Oscar Hart', 1902, 'M', 3, 152),
#  (191, 'Ferris Lindsey', 1952, 'M', 6, 160),
#  (192, 'Kennan Sosa', 1911, 'M', 6, 171),
#  (193, 'Bradley Craig', 1908, 'M', 3, 151),
#  (194, 'Amos Cardenas', 1964, 'M', 3, 163),
#  (195, 'Preston Parks', 2001, 'M', 2, 196),
#  (196, 'Giacomo Douglas', 1933, 'M', 6, 183),
#  (197, 'Merrill Griffith', 2006, 'M', 5, 185),
#  (198, 'Ian Shepard', 1933, 'M', 6, 157),
#  (199, 'Chadwick Riggs', 1908, 'M', 1, 162),
#  (200, 'Chancellor Edwards', 2007, 'F', 1, 161)]

# %% [markdown]
# # all the avaliable tables
#
# Departments(Number, Name, Location)
#
# Employees (SSN,Name,Sex,BirthYear,AssignedTo)
#
# Dependents (HouseHolder,Name,Sex,BirthYear,Relationship)
#
# Supervisors (SSN,StartYear)
#
# Subordinates (SSN,SupervisedBy)
#
# Managers (SSN,Directs,StartYear)
#
# Projects (PNumber,PName,ManagedBy)
#
# WorksOn (Employee,Project,TimeShare)
#
# ## views we have
#
# DataSupervisors(SSN, Name, BirthYear, Sex, AssignedTo, StartYear)
#
# DataManagers (SSN, Name, BirthYear, Sex, AssignedTo, StartYear, Directs)
#
# DataSubordinates (SSN, Name, BirthYear, Sex, AssignedTo,SupervisedBy)

# %% [markdown]
# ![](employess-question-set-scema.png)

# %% [markdown]
# ### 1. Retrieve the name and birth year of the employee’s child with code 350 (we change to 159).

# %%
# %%sql
#
# SELECT Name, BirthYear
# FROM Dependents
# WHERE Relationship = 'Child'
# AND HouseHolder = 159;
# Out:
#  * postgresql://piyush2017:***@127.0.0.1/interviews
# 1 rows affected.
# [('Ian Rogers', 1984)]

# %% [markdown]
# ### 2. For each employee, retrieve the employee name and the name of the department where he works.

# %%
# %%sql
#
# SELECT E.Name, D.Name
# FROM Employees AS E, Departments AS D
# WHERE E.AssignedTo = D.Number;
# Out:
#  * postgresql://piyush2017:***@127.0.0.1/interviews
# 100 rows affected.
# [('Brock Cherry', 'Marketing'),
#  ('Calvin Anthony', 'HR'),
#  ('Tad Hughes', 'Informatics'),
#  ('Odysseus Norton', 'Finance'),
#  ('Vernon Randolph', 'Sales'),
#  ('Colton Riggs', 'Informatics'),
#  ('Brock Key', 'HR'),
#  ('Kasimir Larsen', 'R&D'),
#  ('Barrett Hebert', 'Informatics'),
#  ('Wyatt Nicholson', 'HR'),
#  ('Mufutau Mitchell', 'HR'),
#  ('Lawrence Cote', 'HR'),
#  ('Timon Mcmahon', 'R&D'),
#  ('Malcolm Oconnor', 'Marketing'),
#  ('Odysseus Delgado', 'R&D'),
#  ('Igor Morgan', 'HR'),
#  ('Christopher Jordan', 'Marketing'),
#  ('Nolan Reese', 'Finance'),
#  ('Garth Gomez', 'Informatics'),
#  ('Buckminster Estrada', 'Marketing'),
#  ('Gregory Morin', 'Sales'),
#  ('Troy Chandler', 'Marketing'),
#  ('Chester Atkins', 'R&D'),
#  ('Felix Frye', 'Sales'),
#  ('Wallace Oliver', 'HR'),
#  ('Hakeem Ferrell', 'Finance'),
#  ('Paki Phillips', 'Finance'),
#  ('Shad Whitfield', 'HR'),
#  ('Wylie Cannon', 'Finance'),
#  ('Elvis Buchanan', 'Finance'),
#  ('Brody Mccarty', 'HR'),
#  ('Brett Bentley', 'Informatics'),
#  ('Xanthus Fox', 'Finance'),
#  ('William Dejesus', 'Sales'),
#  ('Phillip Tillman', 'R&D'),
#  ('Kato Martinez', 'Informatics'),
#  ('Nicholas Daugherty', 'Sales'),
#  ('Howard Shepard', 'Sales'),
#  ('Jackson Sellers', 'Marketing'),
#  ('Jack Ramirez', 'Informatics'),
#  ('Wyatt House', 'Sales'),
#  ('Gavin Benton', 'Marketing'),
#  ('Xanthus Holman', 'Sales'),
#  ('Price Chavez', 'Sales'),
#  ('Steven Sawyer', 'Informatics'),
#  ('Tate Hopper', 'Finance'),
#  ('Henry Lane', 'R&D'),
#  ('Dane Medina', 'Sales'),
#  ('Joshua Fernandez', 'R&D'),
#  ('Harlan Rivas', 'Finance'),
#  ('Wade Berger', 'Finance'),
#  ('Louis Townsend', 'Marketing'),
#  ('Marvin Harrell', 'Marketing'),
#  ('Richard Carrillo', 'R&D'),
#  ('Norman Booth', 'Finance'),
#  ('Ray Reid', 'Finance'),
#  ('Xanthus Ortega', 'Sales'),
#  ('Jack Cooper', 'HR'),
#  ('Peter Pearson', 'Finance'),
#  ('Neville Blanchard', 'Finance'),
#  ('Cain Johnston', 'R&D'),
#  ('Tiger Dennis', 'Sales'),
#  ('Marshall Rice', 'R&D'),
#  ('Macaulay Huffman', 'Informatics'),
#  ('Hamilton Porter', 'HR'),
#  ('Joshua Craig', 'Informatics'),
#  ('Colby Glass', 'Informatics'),
#  ('Walker Wiggins', 'Sales'),
#  ('Garrison Bauer', 'Marketing'),
#  ('Clark Meadows', 'R&D'),
#  ('Rudyard Hendrix', 'Sales'),
#  ('Bevis Maxwell', 'Marketing'),
#  ('Ali Robinson', 'Marketing'),
#  ('Dominic Faulkner', 'Marketing'),
#  ('Wyatt Vance', 'Sales'),
#  ('Kenneth Snyder', 'R&D'),
#  ('Jerry Donovan', 'Finance'),
#  ('Dante Jensen', 'Informatics'),
#  ('Hop White', 'Finance'),
#  ('Conan Allison', 'Sales'),
#  ('Hashim Mcclure', 'Finance'),
#  ('Leroy Buck', 'R&D'),
#  ('Leo Austin', 'Informatics'),
#  ('Hop Bender', 'HR'),
#  ('Amir Blackburn', 'R&D'),
#  ('Elmo Mooney', 'R&D'),
#  ('Driscoll Benton', 'R&D'),
#  ('Chase Battle', 'Informatics'),
#  ('Asher Jarvis', 'R&D'),
#  ('Oscar Hart', 'Marketing'),
#  ('Ferris Lindsey', 'R&D'),
#  ('Kennan Sosa', 'R&D'),
#  ('Bradley Craig', 'Marketing'),
#  ('Amos Cardenas', 'Marketing'),
#  ('Preston Parks', 'HR'),
#  ('Giacomo Douglas', 'R&D'),
#  ('Merrill Griffith', 'Finance'),
#  ('Ian Shepard', 'R&D'),
#  ('Chadwick Riggs', 'Sales'),
#  ('Chancellor Edwards', 'Sales')]

# %% [markdown]
# ### 3. Retrieve the names and birth years of female employees older than their supervisor.

# %%
# %%sql
#
# SELECT u.Name, u.BirthYear
# FROM DataSubordinates AS u
# WHERE Sex = 'F'
#     AND u.BirthYear < (
#         SELECT s.BirthYear
#         FROM DataSupervisors AS s
#         WHERE u.SupervisedBy = s.SSN )
# ORDER BY u.Name;
# Out:
#  * postgresql://piyush2017:***@127.0.0.1/interviews
# 24 rows affected.
# [('Asher Jarvis', 1979),
#  ('Brody Mccarty', 1966),
#  ('Chase Battle', 1901),
#  ('Chester Atkins', 1938),
#  ('Dante Jensen', 1916),
#  ('Elvis Buchanan', 1915),
#  ('Felix Frye', 1910),
#  ('Garth Gomez', 1942),
#  ('Gregory Morin', 1926),
#  ('Hamilton Porter', 1969),
#  ('Harlan Rivas', 1922),
#  ('Hop Bender', 1936),
#  ('Jack Cooper', 1904),
#  ('Jerry Donovan', 1914),
#  ('Joshua Craig', 1903),
#  ('Kasimir Larsen', 1958),
#  ('Marshall Rice', 1912),
#  ('Odysseus Norton', 1982),
#  ('Phillip Tillman', 1927),
#  ('Ray Reid', 1933),
#  ('Rudyard Hendrix', 1951),
#  ('Troy Chandler', 1939),
#  ('Wylie Cannon', 1961),
#  ('Xanthus Ortega', 1943)]

# %%
# %%sql
#
# SELECT e.Name, e.BirthYear AS Employee, s.BirthYear AS Supervisor
# FROM DataSubordinates AS e
# RIGHT JOIN DataSupervisors AS s
# ON s.SSN = e.SupervisedBy
# WHERE e.BirthYear < s.BirthYear
# AND e.Sex = 'F'
# ORDER BY e.Name;
# Out:
#  * postgresql://piyush2017:***@127.0.0.1/interviews
# 24 rows affected.
# [('Asher Jarvis', 1979, 2006),
#  ('Brody Mccarty', 1966, 2006),
#  ('Chase Battle', 1901, 1930),
#  ('Chester Atkins', 1938, 1964),
#  ('Dante Jensen', 1916, 1922),
#  ('Elvis Buchanan', 1915, 2008),
#  ('Felix Frye', 1910, 1930),
#  ('Garth Gomez', 1942, 2001),
#  ('Gregory Morin', 1926, 2001),
#  ('Hamilton Porter', 1969, 1979),
#  ('Harlan Rivas', 1922, 1988),
#  ('Hop Bender', 1936, 1971),
#  ('Jack Cooper', 1904, 1911),
#  ('Jerry Donovan', 1914, 1944),
#  ('Joshua Craig', 1903, 1922),
#  ('Kasimir Larsen', 1958, 1984),
#  ('Marshall Rice', 1912, 1952),
#  ('Odysseus Norton', 1982, 1999),
#  ('Phillip Tillman', 1927, 2008),
#  ('Ray Reid', 1933, 1936),
#  ('Rudyard Hendrix', 1951, 1969),
#  ('Troy Chandler', 1939, 1990),
#  ('Wylie Cannon', 1961, 1979),
#  ('Xanthus Ortega', 1943, 1990)]

# %% [markdown]
# ### 4. Retrieve the names of employees who do not have supervisors.

# %%
# %%sql
# SELECT Name
# FROM DataSubordinates
# WHERE SupervisedBy IS NULL;

# %% [markdown]
# ### 5. Retrieve the names of employees who work for the Research department (i.e. R&D) , and the location of the department.

# %%
# %%sql
#
# SELECT e.Name, d.Location
# FROM Employees AS e, Departments AS d
# WHERE d.Name = 'R&D'
# AND e.AssignedTo = d.Number;
# Out:
#  * postgresql://piyush2017:***@127.0.0.1/interviews
# 21 rows affected.
# [('Kasimir Larsen', 'Pisa'),
#  ('Timon Mcmahon', 'Pisa'),
#  ('Odysseus Delgado', 'Pisa'),
#  ('Chester Atkins', 'Pisa'),
#  ('Phillip Tillman', 'Pisa'),
#  ('Henry Lane', 'Pisa'),
#  ('Joshua Fernandez', 'Pisa'),
#  ('Richard Carrillo', 'Pisa'),
#  ('Cain Johnston', 'Pisa'),
#  ('Marshall Rice', 'Pisa'),
#  ('Clark Meadows', 'Pisa'),
#  ('Kenneth Snyder', 'Pisa'),
#  ('Leroy Buck', 'Pisa'),
#  ('Amir Blackburn', 'Pisa'),
#  ('Elmo Mooney', 'Pisa'),
#  ('Driscoll Benton', 'Pisa'),
#  ('Asher Jarvis', 'Pisa'),
#  ('Ferris Lindsey', 'Pisa'),
#  ('Kennan Sosa', 'Pisa'),
#  ('Giacomo Douglas', 'Pisa'),
#  ('Ian Shepard', 'Pisa')]

# %% [markdown]
# ### 6. For every project located in Pisa, list the project number and name, the controlling department name, and the department manager’s name.

# %%
# %%sql
#
# SELECT p.pNumber, p.pName, d.Name, e.Name
# FROM Projects AS p, Departments AS d, Managers AS m, Employees AS e
# WHERE p.ManagedBy = d.Number
# AND m.Directs = d.Number
# AND m.SSN = e.SSN
# AND d.Location = 'Pisa'
# ORDER BY p.pNumber, e.Name;
# Out:
#  * postgresql://piyush2017:***@127.0.0.1/interviews
# 78 rows affected.
# [(1, 'red', 'R&D', 'Cain Johnston'),
#  (1, 'red', 'R&D', 'Colby Glass'),
#  (1, 'red', 'R&D', 'Hamilton Porter'),
#  (1, 'red', 'R&D', 'Henry Lane'),
#  (1, 'red', 'R&D', 'Price Chavez'),
#  (1, 'red', 'R&D', 'Ray Reid'),
#  (1, 'red', 'R&D', 'Richard Carrillo'),
#  (2, 'violet', 'HR', 'Garrison Bauer'),
#  (2, 'violet', 'HR', 'Jack Ramirez'),
#  (2, 'violet', 'HR', 'Neville Blanchard'),
#  (2, 'violet', 'HR', 'Xanthus Ortega'),
#  (3, 'orange', 'Marketing', 'Harlan Rivas'),
#  (3, 'orange', 'Marketing', 'Jack Cooper'),
#  (3, 'orange', 'Marketing', 'Joshua Craig'),
#  (3, 'orange', 'Marketing', 'Steven Sawyer'),
#  (4, 'indigo', 'R&D', 'Cain Johnston'),
#  (4, 'indigo', 'R&D', 'Colby Glass'),
#  (4, 'indigo', 'R&D', 'Hamilton Porter'),
#  (4, 'indigo', 'R&D', 'Henry Lane'),
#  (4, 'indigo', 'R&D', 'Price Chavez'),
#  (4, 'indigo', 'R&D', 'Ray Reid'),
#  (4, 'indigo', 'R&D', 'Richard Carrillo'),
#  (5, 'red', 'R&D', 'Cain Johnston'),
#  (5, 'red', 'R&D', 'Colby Glass'),
#  (5, 'red', 'R&D', 'Hamilton Porter'),
#  (5, 'red', 'R&D', 'Henry Lane'),
#  (5, 'red', 'R&D', 'Price Chavez'),
#  (5, 'red', 'R&D', 'Ray Reid'),
#  (5, 'red', 'R&D', 'Richard Carrillo'),
#  (7, 'red', 'HR', 'Garrison Bauer'),
#  (7, 'red', 'HR', 'Jack Ramirez'),
#  (7, 'red', 'HR', 'Neville Blanchard'),
#  (7, 'red', 'HR', 'Xanthus Ortega'),
#  (8, 'blue', 'Marketing', 'Harlan Rivas'),
#  (8, 'blue', 'Marketing', 'Jack Cooper'),
#  (8, 'blue', 'Marketing', 'Joshua Craig'),
#  (8, 'blue', 'Marketing', 'Steven Sawyer'),
#  (9, 'red', 'HR', 'Garrison Bauer'),
#  (9, 'red', 'HR', 'Jack Ramirez'),
#  (9, 'red', 'HR', 'Neville Blanchard'),
#  (9, 'red', 'HR', 'Xanthus Ortega'),
#  (10, 'violet', 'HR', 'Garrison Bauer'),
#  (10, 'violet', 'HR', 'Jack Ramirez'),
#  (10, 'violet', 'HR', 'Neville Blanchard'),
#  (10, 'violet', 'HR', 'Xanthus Ortega'),
#  (12, 'red', 'HR', 'Garrison Bauer'),
#  (12, 'red', 'HR', 'Jack Ramirez'),
#  (12, 'red', 'HR', 'Neville Blanchard'),
#  (12, 'red', 'HR', 'Xanthus Ortega'),
#  (13, 'orange', 'Sales', 'Dane Medina'),
#  (13, 'orange', 'Sales', 'Gavin Benton'),
#  (13, 'orange', 'Sales', 'Joshua Fernandez'),
#  (13, 'orange', 'Sales', 'Macaulay Huffman'),
#  (13, 'orange', 'Sales', 'Norman Booth'),
#  (13, 'orange', 'Sales', 'Wade Berger'),
#  (13, 'orange', 'Sales', 'Walker Wiggins'),
#  (14, 'yellow', 'Marketing', 'Harlan Rivas'),
#  (14, 'yellow', 'Marketing', 'Jack Cooper'),
#  (14, 'yellow', 'Marketing', 'Joshua Craig'),
#  (14, 'yellow', 'Marketing', 'Steven Sawyer'),
#  (15, 'orange', 'HR', 'Garrison Bauer'),
#  (15, 'orange', 'HR', 'Jack Ramirez'),
#  (15, 'orange', 'HR', 'Neville Blanchard'),
#  (15, 'orange', 'HR', 'Xanthus Ortega'),
#  (17, 'yellow', 'R&D', 'Cain Johnston'),
#  (17, 'yellow', 'R&D', 'Colby Glass'),
#  (17, 'yellow', 'R&D', 'Hamilton Porter'),
#  (17, 'yellow', 'R&D', 'Henry Lane'),
#  (17, 'yellow', 'R&D', 'Price Chavez'),
#  (17, 'yellow', 'R&D', 'Ray Reid'),
#  (17, 'yellow', 'R&D', 'Richard Carrillo'),
#  (18, 'yellow', 'Sales', 'Dane Medina'),
#  (18, 'yellow', 'Sales', 'Gavin Benton'),
#  (18, 'yellow', 'Sales', 'Joshua Fernandez'),
#  (18, 'yellow', 'Sales', 'Macaulay Huffman'),
#  (18, 'yellow', 'Sales', 'Norman Booth'),
#  (18, 'yellow', 'Sales', 'Wade Berger'),
#  (18, 'yellow', 'Sales', 'Walker Wiggins')]

# %%
# %%sql
#
# SELECT p.pNumber, p.pName, d.Name,e.Name
# FROM Projects AS p, Departments AS d, DataManagers AS e
# WHERE p.ManagedBy = D.Number
# AND d.location = 'Pisa'
# AND d.Number = e.Directs
# ORDER BY p.pNumber,e.Name;
# Out:
#  * postgresql://piyush2017:***@127.0.0.1/interviews
# 78 rows affected.
# [(1, 'red', 'R&D', 'Cain Johnston'),
#  (1, 'red', 'R&D', 'Colby Glass'),
#  (1, 'red', 'R&D', 'Hamilton Porter'),
#  (1, 'red', 'R&D', 'Henry Lane'),
#  (1, 'red', 'R&D', 'Price Chavez'),
#  (1, 'red', 'R&D', 'Ray Reid'),
#  (1, 'red', 'R&D', 'Richard Carrillo'),
#  (2, 'violet', 'HR', 'Garrison Bauer'),
#  (2, 'violet', 'HR', 'Jack Ramirez'),
#  (2, 'violet', 'HR', 'Neville Blanchard'),
#  (2, 'violet', 'HR', 'Xanthus Ortega'),
#  (3, 'orange', 'Marketing', 'Harlan Rivas'),
#  (3, 'orange', 'Marketing', 'Jack Cooper'),
#  (3, 'orange', 'Marketing', 'Joshua Craig'),
#  (3, 'orange', 'Marketing', 'Steven Sawyer'),
#  (4, 'indigo', 'R&D', 'Cain Johnston'),
#  (4, 'indigo', 'R&D', 'Colby Glass'),
#  (4, 'indigo', 'R&D', 'Hamilton Porter'),
#  (4, 'indigo', 'R&D', 'Henry Lane'),
#  (4, 'indigo', 'R&D', 'Price Chavez'),
#  (4, 'indigo', 'R&D', 'Ray Reid'),
#  (4, 'indigo', 'R&D', 'Richard Carrillo'),
#  (5, 'red', 'R&D', 'Cain Johnston'),
#  (5, 'red', 'R&D', 'Colby Glass'),
#  (5, 'red', 'R&D', 'Hamilton Porter'),
#  (5, 'red', 'R&D', 'Henry Lane'),
#  (5, 'red', 'R&D', 'Price Chavez'),
#  (5, 'red', 'R&D', 'Ray Reid'),
#  (5, 'red', 'R&D', 'Richard Carrillo'),
#  (7, 'red', 'HR', 'Garrison Bauer'),
#  (7, 'red', 'HR', 'Jack Ramirez'),
#  (7, 'red', 'HR', 'Neville Blanchard'),
#  (7, 'red', 'HR', 'Xanthus Ortega'),
#  (8, 'blue', 'Marketing', 'Harlan Rivas'),
#  (8, 'blue', 'Marketing', 'Jack Cooper'),
#  (8, 'blue', 'Marketing', 'Joshua Craig'),
#  (8, 'blue', 'Marketing', 'Steven Sawyer'),
#  (9, 'red', 'HR', 'Garrison Bauer'),
#  (9, 'red', 'HR', 'Jack Ramirez'),
#  (9, 'red', 'HR', 'Neville Blanchard'),
#  (9, 'red', 'HR', 'Xanthus Ortega'),
#  (10, 'violet', 'HR', 'Garrison Bauer'),
#  (10, 'violet', 'HR', 'Jack Ramirez'),
#  (10, 'violet', 'HR', 'Neville Blanchard'),
#  (10, 'violet', 'HR', 'Xanthus Ortega'),
#  (12, 'red', 'HR', 'Garrison Bauer'),
#  (12, 'red', 'HR', 'Jack Ramirez'),
#  (12, 'red', 'HR', 'Neville Blanchard'),
#  (12, 'red', 'HR', 'Xanthus Ortega'),
#  (13, 'orange', 'Sales', 'Dane Medina'),
#  (13, 'orange', 'Sales', 'Gavin Benton'),
#  (13, 'orange', 'Sales', 'Joshua Fernandez'),
#  (13, 'orange', 'Sales', 'Macaulay Huffman'),
#  (13, 'orange', 'Sales', 'Norman Booth'),
#  (13, 'orange', 'Sales', 'Wade Berger'),
#  (13, 'orange', 'Sales', 'Walker Wiggins'),
#  (14, 'yellow', 'Marketing', 'Harlan Rivas'),
#  (14, 'yellow', 'Marketing', 'Jack Cooper'),
#  (14, 'yellow', 'Marketing', 'Joshua Craig'),
#  (14, 'yellow', 'Marketing', 'Steven Sawyer'),
#  (15, 'orange', 'HR', 'Garrison Bauer'),
#  (15, 'orange', 'HR', 'Jack Ramirez'),
#  (15, 'orange', 'HR', 'Neville Blanchard'),
#  (15, 'orange', 'HR', 'Xanthus Ortega'),
#  (17, 'yellow', 'R&D', 'Cain Johnston'),
#  (17, 'yellow', 'R&D', 'Colby Glass'),
#  (17, 'yellow', 'R&D', 'Hamilton Porter'),
#  (17, 'yellow', 'R&D', 'Henry Lane'),
#  (17, 'yellow', 'R&D', 'Price Chavez'),
#  (17, 'yellow', 'R&D', 'Ray Reid'),
#  (17, 'yellow', 'R&D', 'Richard Carrillo'),
#  (18, 'yellow', 'Sales', 'Dane Medina'),
#  (18, 'yellow', 'Sales', 'Gavin Benton'),
#  (18, 'yellow', 'Sales', 'Joshua Fernandez'),
#  (18, 'yellow', 'Sales', 'Macaulay Huffman'),
#  (18, 'yellow', 'Sales', 'Norman Booth'),
#  (18, 'yellow', 'Sales', 'Wade Berger'),
#  (18, 'yellow', 'Sales', 'Walker Wiggins')]

# %% [markdown]
# ### 7. Retrieve the names of employees who have no dependents.

# %%
# %%sql
# SELECT e.Name
# FROM Employees AS e
# WHERE NOT EXISTS (
#     SELECT * FROM Dependents D WHERE e.SSN = d.HouseHolder);
# Out:
#  * postgresql://piyush2017:***@127.0.0.1/interviews
# 30 rows affected.
# [('Odysseus Norton',),
#  ('Vernon Randolph',),
#  ('Kasimir Larsen',),
#  ('Malcolm Oconnor',),
#  ('Igor Morgan',),
#  ('Christopher Jordan',),
#  ('Felix Frye',),
#  ('Wallace Oliver',),
#  ('Wylie Cannon',),
#  ('Elvis Buchanan',),
#  ('Brett Bentley',),
#  ('Xanthus Fox',),
#  ('William Dejesus',),
#  ('Richard Carrillo',),
#  ('Ray Reid',),
#  ('Xanthus Ortega',),
#  ('Jack Cooper',),
#  ('Neville Blanchard',),
#  ('Macaulay Huffman',),
#  ('Garrison Bauer',),
#  ('Dominic Faulkner',),
#  ('Leroy Buck',),
#  ('Hop Bender',),
#  ('Amir Blackburn',),
#  ('Elmo Mooney',),
#  ('Asher Jarvis',),
#  ('Kennan Sosa',),
#  ('Bradley Craig',),
#  ('Merrill Griffith',),
#  ('Chancellor Edwards',)]

# %%
# %%sql
#
# SELECT Name FROM Employees
#
# EXCEPT
#
# SELECT e.Name
# FROM Employees AS e, Dependents AS d
# WHERE e.SSN = d.HouseHolder;
# Out:
#  * postgresql://piyush2017:***@127.0.0.1/interviews
# 30 rows affected.
# [('Kennan Sosa',),
#  ('Macaulay Huffman',),
#  ('William Dejesus',),
#  ('Odysseus Norton',),
#  ('Vernon Randolph',),
#  ('Wallace Oliver',),
#  ('Xanthus Ortega',),
#  ('Leroy Buck',),
#  ('Igor Morgan',),
#  ('Garrison Bauer',),
#  ('Hop Bender',),
#  ('Merrill Griffith',),
#  ('Jack Cooper',),
#  ('Brett Bentley',),
#  ('Chancellor Edwards',),
#  ('Christopher Jordan',),
#  ('Xanthus Fox',),
#  ('Bradley Craig',),
#  ('Elvis Buchanan',),
#  ('Neville Blanchard',),
#  ('Wylie Cannon',),
#  ('Asher Jarvis',),
#  ('Ray Reid',),
#  ('Felix Frye',),
#  ('Richard Carrillo',),
#  ('Amir Blackburn',),
#  ('Elmo Mooney',),
#  ('Dominic Faulkner',),
#  ('Malcolm Oconnor',),
#  ('Kasimir Larsen',)]

# %% [markdown]
# ### 8. Retrieve the names of supervisors who have at least one dependent.

# %%
# %%sql
# SELECT e.Name
# FROM Employees AS e, Supervisors AS s
# WHERE e.SSN = s.SSN
#         AND EXISTS (
#         SELECT *
#         FROM Dependents AS d
#         WHERE d.HouseHolder = e.SSN)
# ORDER BY e.Name;
# Out:
#  * postgresql://piyush2017:***@127.0.0.1/interviews
# 34 rows affected.
# [('Ali Robinson',),
#  ('Amos Cardenas',),
#  ('Bevis Maxwell',),
#  ('Cain Johnston',),
#  ('Chadwick Riggs',),
#  ('Chase Battle',),
#  ('Clark Meadows',),
#  ('Colby Glass',),
#  ('Conan Allison',),
#  ('Dante Jensen',),
#  ('Driscoll Benton',),
#  ('Ferris Lindsey',),
#  ('Giacomo Douglas',),
#  ('Hamilton Porter',),
#  ('Harlan Rivas',),
#  ('Hashim Mcclure',),
#  ('Hop White',),
#  ('Ian Shepard',),
#  ('Jerry Donovan',),
#  ('Joshua Craig',),
#  ('Kenneth Snyder',),
#  ('Leo Austin',),
#  ('Louis Townsend',),
#  ('Marshall Rice',),
#  ('Marvin Harrell',),
#  ('Norman Booth',),
#  ('Oscar Hart',),
#  ('Peter Pearson',),
#  ('Preston Parks',),
#  ('Rudyard Hendrix',),
#  ('Tiger Dennis',),
#  ('Wade Berger',),
#  ('Walker Wiggins',),
#  ('Wyatt Vance',)]

# %%
# %%sql
#
# SELECT DISTINCT s.Name
# FROM Dependents AS d, DataSupervisors AS s
# WHERE d.HouseHolder = s.SSN
# ORDER BY s.Name;
# Out:
#  * postgresql://piyush2017:***@127.0.0.1/interviews
# 34 rows affected.
# [('Ali Robinson',),
#  ('Amos Cardenas',),
#  ('Bevis Maxwell',),
#  ('Cain Johnston',),
#  ('Chadwick Riggs',),
#  ('Chase Battle',),
#  ('Clark Meadows',),
#  ('Colby Glass',),
#  ('Conan Allison',),
#  ('Dante Jensen',),
#  ('Driscoll Benton',),
#  ('Ferris Lindsey',),
#  ('Giacomo Douglas',),
#  ('Hamilton Porter',),
#  ('Harlan Rivas',),
#  ('Hashim Mcclure',),
#  ('Hop White',),
#  ('Ian Shepard',),
#  ('Jerry Donovan',),
#  ('Joshua Craig',),
#  ('Kenneth Snyder',),
#  ('Leo Austin',),
#  ('Louis Townsend',),
#  ('Marshall Rice',),
#  ('Marvin Harrell',),
#  ('Norman Booth',),
#  ('Oscar Hart',),
#  ('Peter Pearson',),
#  ('Preston Parks',),
#  ('Rudyard Hendrix',),
#  ('Tiger Dennis',),
#  ('Wade Berger',),
#  ('Walker Wiggins',),
#  ('Wyatt Vance',)]

# %%
# %%sql
# SELECT Name
# FROM DataSupervisors AS ds
# WHERE EXISTS (
#         SELECT *
#         FROM Dependents AS d
#         WHERE ds.SSN = d.HouseHolder)
# ORDER BY Name;
# Out:
#  * postgresql://piyush2017:***@127.0.0.1/interviews
# 34 rows affected.
# [('Ali Robinson',),
#  ('Amos Cardenas',),
#  ('Bevis Maxwell',),
#  ('Cain Johnston',),
#  ('Chadwick Riggs',),
#  ('Chase Battle',),
#  ('Clark Meadows',),
#  ('Colby Glass',),
#  ('Conan Allison',),
#  ('Dante Jensen',),
#  ('Driscoll Benton',),
#  ('Ferris Lindsey',),
#  ('Giacomo Douglas',),
#  ('Hamilton Porter',),
#  ('Harlan Rivas',),
#  ('Hashim Mcclure',),
#  ('Hop White',),
#  ('Ian Shepard',),
#  ('Jerry Donovan',),
#  ('Joshua Craig',),
#  ('Kenneth Snyder',),
#  ('Leo Austin',),
#  ('Louis Townsend',),
#  ('Marshall Rice',),
#  ('Marvin Harrell',),
#  ('Norman Booth',),
#  ('Oscar Hart',),
#  ('Peter Pearson',),
#  ('Preston Parks',),
#  ('Rudyard Hendrix',),
#  ('Tiger Dennis',),
#  ('Wade Berger',),
#  ('Walker Wiggins',),
#  ('Wyatt Vance',)]

# %% [markdown]
# ### 9. For each employee retrieve the employees name and the name of the immediate supervisor.

# %%
# %%sql
# SELECT ds.Name AS Employee, e.Name As Supervisor
# FROM DataSubordinates AS ds, Employees AS e
# WHERE ds.SupervisedBy = e.SSN;
# Out:
#  * postgresql://piyush2017:***@127.0.0.1/interviews
# 100 rows affected.
# [('Brock Cherry', 'Hop White'),
#  ('Calvin Anthony', 'Kennan Sosa'),
#  ('Tad Hughes', 'Jerry Donovan'),
#  ('Odysseus Norton', 'Hashim Mcclure'),
#  ('Vernon Randolph', 'Hop Bender'),
#  ('Colton Riggs', 'Oscar Hart'),
#  ('Brock Key', 'Dante Jensen'),
#  ('Kasimir Larsen', 'Amir Blackburn'),
#  ('Barrett Hebert', 'Conan Allison'),
#  ('Wyatt Nicholson', 'Chase Battle'),
#  ('Mufutau Mitchell', 'Ray Reid'),
#  ('Lawrence Cote', 'Clark Meadows'),
#  ('Timon Mcmahon', 'Jerry Donovan'),
#  ('Malcolm Oconnor', 'Hop Bender'),
#  ('Odysseus Delgado', 'Kennan Sosa'),
#  ('Igor Morgan', 'Macaulay Huffman'),
#  ('Christopher Jordan', 'Bevis Maxwell'),
#  ('Nolan Reese', 'Rudyard Hendrix'),
#  ('Garth Gomez', 'Leroy Buck'),
#  ('Buckminster Estrada', 'Rudyard Hendrix'),
#  ('Gregory Morin', 'Preston Parks'),
#  ('Troy Chandler', 'Wyatt Vance'),
#  ('Chester Atkins', 'Amos Cardenas'),
#  ('Felix Frye', 'Richard Carrillo'),
#  ('Wallace Oliver', 'Bevis Maxwell'),
#  ('Hakeem Ferrell', 'Marvin Harrell'),
#  ('Paki Phillips', 'Dante Jensen'),
#  ('Shad Whitfield', 'Peter Pearson'),
#  ('Wylie Cannon', 'Driscoll Benton'),
#  ('Elvis Buchanan', 'Colby Glass'),
#  ('Brody Mccarty', 'Merrill Griffith'),
#  ('Brett Bentley', 'Chancellor Edwards'),
#  ('Xanthus Fox', 'Neville Blanchard'),
#  ('William Dejesus', 'Kenneth Snyder'),
#  ('Phillip Tillman', 'Colby Glass'),
#  ('Kato Martinez', 'Harlan Rivas'),
#  ('Nicholas Daugherty', 'Leo Austin'),
#  ('Howard Shepard', 'Merrill Griffith'),
#  ('Jackson Sellers', 'Oscar Hart'),
#  ('Jack Ramirez', 'Rudyard Hendrix'),
#  ('Wyatt House', 'Elmo Mooney'),
#  ('Gavin Benton', 'Hop White'),
#  ('Xanthus Holman', 'Asher Jarvis'),
#  ('Price Chavez', 'Bradley Craig'),
#  ('Steven Sawyer', 'Neville Blanchard'),
#  ('Tate Hopper', 'Jack Cooper'),
#  ('Henry Lane', 'Ferris Lindsey'),
#  ('Dane Medina', 'Driscoll Benton'),
#  ('Joshua Fernandez', 'Bevis Maxwell'),
#  ('Harlan Rivas', 'Leo Austin'),
#  ('Wade Berger', 'Bradley Craig'),
#  ('Louis Townsend', 'Louis Townsend'),
#  ('Marvin Harrell', 'Peter Pearson'),
#  ('Richard Carrillo', 'Kenneth Snyder'),
#  ('Norman Booth', 'Ian Shepard'),
#  ('Ray Reid', 'Hop Bender'),
#  ('Xanthus Ortega', 'Wyatt Vance'),
#  ('Jack Cooper', 'Kennan Sosa'),
#  ('Peter Pearson', 'Dominic Faulkner'),
#  ('Neville Blanchard', 'Peter Pearson'),
#  ('Cain Johnston', 'Norman Booth'),
#  ('Tiger Dennis', 'Harlan Rivas'),
#  ('Marshall Rice', 'Ferris Lindsey'),
#  ('Macaulay Huffman', 'Chase Battle'),
#  ('Hamilton Porter', 'Asher Jarvis'),
#  ('Joshua Craig', 'Harlan Rivas'),
#  ('Colby Glass', 'Jack Cooper'),
#  ('Walker Wiggins', 'Bradley Craig'),
#  ('Garrison Bauer', 'Hop Bender'),
#  ('Clark Meadows', 'Rudyard Hendrix'),
#  ('Rudyard Hendrix', 'Hamilton Porter'),
#  ('Bevis Maxwell', 'Hop Bender'),
#  ('Ali Robinson', 'Hop White'),
#  ('Dominic Faulkner', 'Giacomo Douglas'),
#  ('Wyatt Vance', 'Peter Pearson'),
#  ('Kenneth Snyder', 'Elmo Mooney'),
#  ('Jerry Donovan', 'Peter Pearson'),
#  ('Dante Jensen', 'Harlan Rivas'),
#  ('Hop White', 'Asher Jarvis'),
#  ('Conan Allison', 'Walker Wiggins'),
#  ('Hashim Mcclure', 'Ferris Lindsey'),
#  ('Leroy Buck', 'Hamilton Porter'),
#  ('Leo Austin', 'Driscoll Benton'),
#  ('Hop Bender', 'Bevis Maxwell'),
#  ('Amir Blackburn', 'Marvin Harrell'),
#  ('Elmo Mooney', 'Colby Glass'),
#  ('Driscoll Benton', 'Richard Carrillo'),
#  ('Chase Battle', 'Richard Carrillo'),
#  ('Asher Jarvis', 'Merrill Griffith'),
#  ('Oscar Hart', 'Louis Townsend'),
#  ('Ferris Lindsey', 'Neville Blanchard'),
#  ('Kennan Sosa', 'Rudyard Hendrix'),
#  ('Bradley Craig', 'Wade Berger'),
#  ('Amos Cardenas', 'Marshall Rice'),
#  ('Preston Parks', 'Giacomo Douglas'),
#  ('Giacomo Douglas', 'Leo Austin'),
#  ('Merrill Griffith', 'Amir Blackburn'),
#  ('Ian Shepard', 'Xanthus Ortega'),
#  ('Chadwick Riggs', 'Tiger Dennis'),
#  ('Chancellor Edwards', 'Cain Johnston')]

# %% [markdown]
# ### 10. Retrieve the names of employees who have a dependent with the same sex.

# %%
# %%sql
# SELECT e.Name
# FROM Employees AS e, Dependents AS d
# WHERE e.SSN = d.HouseHolder
# AND e.Sex = d.Sex;
# Out:
#  * postgresql://piyush2017:***@127.0.0.1/interviews
# 56 rows affected.
# [('Chadwick Riggs',),
#  ('Joshua Craig',),
#  ('Calvin Anthony',),
#  ('Marvin Harrell',),
#  ('Conan Allison',),
#  ('Jack Ramirez',),
#  ('Hakeem Ferrell',),
#  ('Ali Robinson',),
#  ('Harlan Rivas',),
#  ('Chase Battle',),
#  ('Colby Glass',),
#  ('Ferris Lindsey',),
#  ('Hashim Mcclure',),
#  ('Leo Austin',),
#  ('Jackson Sellers',),
#  ('Xanthus Holman',),
#  ('Gregory Morin',),
#  ('Shad Whitfield',),
#  ('Harlan Rivas',),
#  ('Howard Shepard',),
#  ('Rudyard Hendrix',),
#  ('Xanthus Holman',),
#  ('Joshua Fernandez',),
#  ('Xanthus Holman',),
#  ('Rudyard Hendrix',),
#  ('Mufutau Mitchell',),
#  ('Phillip Tillman',),
#  ('Jackson Sellers',),
#  ('Clark Meadows',),
#  ('Timon Mcmahon',),
#  ('Calvin Anthony',),
#  ('Paki Phillips',),
#  ('Brock Key',),
#  ('Troy Chandler',),
#  ('Nicholas Daugherty',),
#  ('Wyatt House',),
#  ('Barrett Hebert',),
#  ('Hakeem Ferrell',),
#  ('Hashim Mcclure',),
#  ('Colby Glass',),
#  ('Marshall Rice',),
#  ('Lawrence Cote',),
#  ('Kenneth Snyder',),
#  ('Hop White',),
#  ('Ali Robinson',),
#  ('Jerry Donovan',),
#  ('Henry Lane',),
#  ('Cain Johnston',),
#  ('Price Chavez',),
#  ('Howard Shepard',),
#  ('Steven Sawyer',),
#  ('Tate Hopper',),
#  ('Walker Wiggins',),
#  ('Wade Berger',),
#  ('Ian Shepard',),
#  ('Buckminster Estrada',)]

# %% [markdown]
# ### 11. For each employee retrieve the employees name and the social security number, the name of the project on which he works, and the name of the department that manages the project, sorted by the names of the department and the employee.

# %%
# %%sql
#
# Select e.Name, e.SSN, p.PName AS Project_Name , d.Name AS Department_Name
# FROM Employees AS e, Departments AS d, Projects As p, WorksOn AS w
# WHERE e.AssignedTo = d.Number
# AND d.Number = p.ManagedBy
# AND e.SSN = w.employee
# ORDER BY d.Name, e.Name;
# Out:
#  * postgresql://piyush2017:***@127.0.0.1/interviews
# 332 rows affected.
# [('Elvis Buchanan', 130, 'yellow', 'Finance'),
#  ('Elvis Buchanan', 130, 'violet', 'Finance'),
#  ('Elvis Buchanan', 130, 'indigo', 'Finance'),
#  ('Elvis Buchanan', 130, 'red', 'Finance'),
#  ('Hakeem Ferrell', 126, 'yellow', 'Finance'),
#  ('Hakeem Ferrell', 126, 'red', 'Finance'),
#  ('Hakeem Ferrell', 126, 'indigo', 'Finance'),
#  ('Hakeem Ferrell', 126, 'violet', 'Finance'),
#  ('Harlan Rivas', 150, 'yellow', 'Finance'),
#  ('Harlan Rivas', 150, 'violet', 'Finance'),
#  ('Harlan Rivas', 150, 'indigo', 'Finance'),
#  ('Harlan Rivas', 150, 'red', 'Finance'),
#  ('Hashim Mcclure', 181, 'indigo', 'Finance'),
#  ('Hashim Mcclure', 181, 'red', 'Finance'),
#  ('Hashim Mcclure', 181, 'yellow', 'Finance'),
#  ('Hashim Mcclure', 181, 'violet', 'Finance'),
#  ('Hop White', 179, 'indigo', 'Finance'),
#  ('Hop White', 179, 'yellow', 'Finance'),
#  ('Hop White', 179, 'violet', 'Finance'),
#  ('Hop White', 179, 'red', 'Finance'),
#  ('Jerry Donovan', 177, 'indigo', 'Finance'),
#  ('Jerry Donovan', 177, 'violet', 'Finance'),
#  ('Jerry Donovan', 177, 'yellow', 'Finance'),
#  ('Jerry Donovan', 177, 'red', 'Finance'),
#  ('Merrill Griffith', 197, 'yellow', 'Finance'),
#  ('Merrill Griffith', 197, 'red', 'Finance'),
#  ('Merrill Griffith', 197, 'indigo', 'Finance'),
#  ('Merrill Griffith', 197, 'violet', 'Finance'),
#  ('Neville Blanchard', 160, 'yellow', 'Finance'),
#  ('Neville Blanchard', 160, 'indigo', 'Finance'),
#  ('Neville Blanchard', 160, 'red', 'Finance'),
#  ('Neville Blanchard', 160, 'violet', 'Finance'),
#  ('Nolan Reese', 118, 'yellow', 'Finance'),
#  ('Nolan Reese', 118, 'indigo', 'Finance'),
#  ('Nolan Reese', 118, 'violet', 'Finance'),
#  ('Nolan Reese', 118, 'red', 'Finance'),
#  ('Norman Booth', 155, 'yellow', 'Finance'),
#  ('Norman Booth', 155, 'violet', 'Finance'),
#  ('Norman Booth', 155, 'indigo', 'Finance'),
#  ('Norman Booth', 155, 'red', 'Finance'),
#  ('Odysseus Norton', 104, 'indigo', 'Finance'),
#  ('Odysseus Norton', 104, 'violet', 'Finance'),
#  ('Odysseus Norton', 104, 'yellow', 'Finance'),
#  ('Odysseus Norton', 104, 'red', 'Finance'),
#  ('Paki Phillips', 127, 'violet', 'Finance'),
#  ('Paki Phillips', 127, 'yellow', 'Finance'),
#  ('Paki Phillips', 127, 'red', 'Finance'),
#  ('Paki Phillips', 127, 'indigo', 'Finance'),
#  ('Peter Pearson', 159, 'yellow', 'Finance'),
#  ('Peter Pearson', 159, 'indigo', 'Finance'),
#  ('Peter Pearson', 159, 'red', 'Finance'),
#  ('Peter Pearson', 159, 'violet', 'Finance'),
#  ('Ray Reid', 156, 'yellow', 'Finance'),
#  ('Ray Reid', 156, 'red', 'Finance'),
#  ('Ray Reid', 156, 'violet', 'Finance'),
#  ('Ray Reid', 156, 'indigo', 'Finance'),
#  ('Tate Hopper', 146, 'yellow', 'Finance'),
#  ('Tate Hopper', 146, 'violet', 'Finance'),
#  ('Tate Hopper', 146, 'indigo', 'Finance'),
#  ('Tate Hopper', 146, 'red', 'Finance'),
#  ('Wade Berger', 151, 'red', 'Finance'),
#  ('Wade Berger', 151, 'indigo', 'Finance'),
#  ('Wade Berger', 151, 'yellow', 'Finance'),
#  ('Wade Berger', 151, 'violet', 'Finance'),
#  ('Wylie Cannon', 129, 'red', 'Finance'),
#  ('Wylie Cannon', 129, 'yellow', 'Finance'),
#  ('Wylie Cannon', 129, 'violet', 'Finance'),
#  ('Wylie Cannon', 129, 'indigo', 'Finance'),
#  ('Xanthus Fox', 133, 'violet', 'Finance'),
#  ('Xanthus Fox', 133, 'red', 'Finance'),
#  ('Xanthus Fox', 133, 'yellow', 'Finance'),
#  ('Xanthus Fox', 133, 'indigo', 'Finance'),
#  ('Brock Key', 107, 'red', 'HR'),
#  ('Brock Key', 107, 'orange', 'HR'),
#  ('Brock Key', 107, 'violet', 'HR'),
#  ('Brock Key', 107, 'red', 'HR'),
#  ('Brock Key', 107, 'red', 'HR'),
#  ('Brock Key', 107, 'violet', 'HR'),
#  ('Brody Mccarty', 131, 'violet', 'HR'),
#  ('Brody Mccarty', 131, 'red', 'HR'),
#  ('Brody Mccarty', 131, 'red', 'HR'),
#  ('Brody Mccarty', 131, 'violet', 'HR'),
#  ('Brody Mccarty', 131, 'red', 'HR'),
#  ('Brody Mccarty', 131, 'orange', 'HR'),
#  ('Calvin Anthony', 102, 'orange', 'HR'),
#  ('Calvin Anthony', 102, 'red', 'HR'),
#  ('Calvin Anthony', 102, 'violet', 'HR'),
#  ('Calvin Anthony', 102, 'red', 'HR'),
#  ('Calvin Anthony', 102, 'violet', 'HR'),
#  ('Calvin Anthony', 102, 'red', 'HR'),
#  ('Hamilton Porter', 165, 'red', 'HR'),
#  ('Hamilton Porter', 165, 'violet', 'HR'),
#  ('Hamilton Porter', 165, 'red', 'HR'),
#  ('Hamilton Porter', 165, 'violet', 'HR'),
#  ('Hamilton Porter', 165, 'red', 'HR'),
#  ('Hamilton Porter', 165, 'orange', 'HR'),
#  ('Hop Bender', 184, 'violet', 'HR'),
#  ('Hop Bender', 184, 'orange', 'HR'),
#  ('Hop Bender', 184, 'red', 'HR'),
#  ('Hop Bender', 184, 'violet', 'HR'),
#  ('Hop Bender', 184, 'red', 'HR'),
#  ('Hop Bender', 184, 'red', 'HR'),
#  ('Igor Morgan', 116, 'red', 'HR'),
#  ('Igor Morgan', 116, 'orange', 'HR'),
#  ('Igor Morgan', 116, 'red', 'HR'),
#  ('Igor Morgan', 116, 'violet', 'HR'),
#  ('Igor Morgan', 116, 'red', 'HR'),
#  ('Igor Morgan', 116, 'violet', 'HR'),
#  ('Jack Cooper', 158, 'orange', 'HR'),
#  ('Jack Cooper', 158, 'red', 'HR'),
#  ('Jack Cooper', 158, 'violet', 'HR'),
#  ('Jack Cooper', 158, 'red', 'HR'),
#  ('Jack Cooper', 158, 'red', 'HR'),
#  ('Jack Cooper', 158, 'violet', 'HR'),
#  ('Lawrence Cote', 112, 'violet', 'HR'),
#  ('Lawrence Cote', 112, 'red', 'HR'),
#  ('Lawrence Cote', 112, 'violet', 'HR'),
#  ('Lawrence Cote', 112, 'red', 'HR'),
#  ('Lawrence Cote', 112, 'red', 'HR'),
#  ('Lawrence Cote', 112, 'orange', 'HR'),
#  ('Mufutau Mitchell', 111, 'red', 'HR'),
#  ('Mufutau Mitchell', 111, 'red', 'HR'),
#  ('Mufutau Mitchell', 111, 'violet', 'HR'),
#  ('Mufutau Mitchell', 111, 'red', 'HR'),
#  ('Mufutau Mitchell', 111, 'orange', 'HR'),
#  ('Mufutau Mitchell', 111, 'violet', 'HR'),
#  ('Preston Parks', 195, 'red', 'HR'),
#  ('Preston Parks', 195, 'violet', 'HR'),
#  ('Preston Parks', 195, 'red', 'HR'),
#  ('Preston Parks', 195, 'violet', 'HR'),
#  ('Preston Parks', 195, 'red', 'HR'),
#  ('Preston Parks', 195, 'orange', 'HR'),
#  ('Shad Whitfield', 128, 'red', 'HR'),
#  ('Shad Whitfield', 128, 'violet', 'HR'),
#  ('Shad Whitfield', 128, 'red', 'HR'),
#  ('Shad Whitfield', 128, 'orange', 'HR'),
#  ('Shad Whitfield', 128, 'violet', 'HR'),
#  ('Shad Whitfield', 128, 'red', 'HR'),
#  ('Wallace Oliver', 125, 'orange', 'HR'),
#  ('Wallace Oliver', 125, 'red', 'HR'),
#  ('Wallace Oliver', 125, 'red', 'HR'),
#  ('Wallace Oliver', 125, 'violet', 'HR'),
#  ('Wallace Oliver', 125, 'red', 'HR'),
#  ('Wallace Oliver', 125, 'violet', 'HR'),
#  ('Wyatt Nicholson', 110, 'red', 'HR'),
#  ('Wyatt Nicholson', 110, 'red', 'HR'),
#  ('Wyatt Nicholson', 110, 'violet', 'HR'),
#  ('Wyatt Nicholson', 110, 'red', 'HR'),
#  ('Wyatt Nicholson', 110, 'orange', 'HR'),
#  ('Wyatt Nicholson', 110, 'violet', 'HR'),
#  ('Barrett Hebert', 109, 'violet', 'Informatics'),
#  ('Brett Bentley', 132, 'violet', 'Informatics'),
#  ('Chase Battle', 188, 'violet', 'Informatics'),
#  ('Colby Glass', 167, 'violet', 'Informatics'),
#  ('Colton Riggs', 106, 'violet', 'Informatics'),
#  ('Dante Jensen', 178, 'violet', 'Informatics'),
#  ('Garth Gomez', 119, 'violet', 'Informatics'),
#  ('Jack Ramirez', 140, 'violet', 'Informatics'),
#  ('Joshua Craig', 166, 'violet', 'Informatics'),
#  ('Kato Martinez', 136, 'violet', 'Informatics'),
#  ('Leo Austin', 183, 'violet', 'Informatics'),
#  ('Macaulay Huffman', 164, 'violet', 'Informatics'),
#  ('Steven Sawyer', 145, 'violet', 'Informatics'),
#  ('Tad Hughes', 103, 'violet', 'Informatics'),
#  ('Ali Robinson', 173, 'yellow', 'Marketing'),
#  ('Ali Robinson', 173, 'blue', 'Marketing'),
#  ('Ali Robinson', 173, 'orange', 'Marketing'),
#  ('Amos Cardenas', 194, 'blue', 'Marketing'),
#  ('Amos Cardenas', 194, 'yellow', 'Marketing'),
#  ('Amos Cardenas', 194, 'orange', 'Marketing'),
#  ('Bevis Maxwell', 172, 'yellow', 'Marketing'),
#  ('Bevis Maxwell', 172, 'blue', 'Marketing'),
#  ('Bevis Maxwell', 172, 'orange', 'Marketing'),
#  ('Bradley Craig', 193, 'blue', 'Marketing'),
#  ('Bradley Craig', 193, 'yellow', 'Marketing'),
#  ('Bradley Craig', 193, 'orange', 'Marketing'),
#  ('Brock Cherry', 101, 'orange', 'Marketing'),
#  ('Brock Cherry', 101, 'yellow', 'Marketing'),
#  ('Brock Cherry', 101, 'blue', 'Marketing'),
#  ('Buckminster Estrada', 120, 'yellow', 'Marketing'),
#  ('Buckminster Estrada', 120, 'blue', 'Marketing'),
#  ('Buckminster Estrada', 120, 'orange', 'Marketing'),
#  ('Christopher Jordan', 117, 'blue', 'Marketing'),
#  ('Christopher Jordan', 117, 'yellow', 'Marketing'),
#  ('Christopher Jordan', 117, 'orange', 'Marketing'),
#  ('Dominic Faulkner', 174, 'orange', 'Marketing'),
#  ('Dominic Faulkner', 174, 'blue', 'Marketing'),
#  ('Dominic Faulkner', 174, 'yellow', 'Marketing'),
#  ('Garrison Bauer', 169, 'yellow', 'Marketing'),
#  ('Garrison Bauer', 169, 'blue', 'Marketing'),
#  ('Garrison Bauer', 169, 'orange', 'Marketing'),
#  ('Gavin Benton', 142, 'yellow', 'Marketing'),
#  ('Gavin Benton', 142, 'orange', 'Marketing'),
#  ('Gavin Benton', 142, 'blue', 'Marketing'),
#  ('Jackson Sellers', 139, 'orange', 'Marketing'),
#  ('Jackson Sellers', 139, 'yellow', 'Marketing'),
#  ('Jackson Sellers', 139, 'blue', 'Marketing'),
#  ('Louis Townsend', 152, 'blue', 'Marketing'),
#  ('Louis Townsend', 152, 'orange', 'Marketing'),
#  ('Louis Townsend', 152, 'yellow', 'Marketing'),
#  ('Malcolm Oconnor', 114, 'blue', 'Marketing'),
#  ('Malcolm Oconnor', 114, 'orange', 'Marketing'),
#  ('Malcolm Oconnor', 114, 'yellow', 'Marketing'),
#  ('Marvin Harrell', 153, 'orange', 'Marketing'),
#  ('Marvin Harrell', 153, 'blue', 'Marketing'),
#  ('Marvin Harrell', 153, 'yellow', 'Marketing'),
#  ('Oscar Hart', 190, 'blue', 'Marketing'),
#  ('Oscar Hart', 190, 'yellow', 'Marketing'),
#  ('Oscar Hart', 190, 'orange', 'Marketing'),
#  ('Troy Chandler', 122, 'orange', 'Marketing'),
#  ('Troy Chandler', 122, 'yellow', 'Marketing'),
#  ('Troy Chandler', 122, 'blue', 'Marketing'),
#  ('Amir Blackburn', 185, 'yellow', 'R&D'),
#  ('Amir Blackburn', 185, 'red', 'R&D'),
#  ('Amir Blackburn', 185, 'indigo', 'R&D'),
#  ('Amir Blackburn', 185, 'red', 'R&D'),
#  ('Asher Jarvis', 189, 'red', 'R&D'),
#  ('Asher Jarvis', 189, 'yellow', 'R&D'),
#  ('Asher Jarvis', 189, 'red', 'R&D'),
#  ('Asher Jarvis', 189, 'indigo', 'R&D'),
#  ('Cain Johnston', 161, 'indigo', 'R&D'),
#  ('Cain Johnston', 161, 'yellow', 'R&D'),
#  ('Cain Johnston', 161, 'red', 'R&D'),
#  ('Cain Johnston', 161, 'red', 'R&D'),
#  ('Chester Atkins', 123, 'red', 'R&D'),
#  ('Chester Atkins', 123, 'red', 'R&D'),
#  ('Chester Atkins', 123, 'indigo', 'R&D'),
#  ('Chester Atkins', 123, 'yellow', 'R&D'),
#  ('Clark Meadows', 170, 'red', 'R&D'),
#  ('Clark Meadows', 170, 'yellow', 'R&D'),
#  ('Clark Meadows', 170, 'indigo', 'R&D'),
#  ('Clark Meadows', 170, 'red', 'R&D'),
#  ('Driscoll Benton', 187, 'yellow', 'R&D'),
#  ('Driscoll Benton', 187, 'red', 'R&D'),
#  ('Driscoll Benton', 187, 'red', 'R&D'),
#  ('Driscoll Benton', 187, 'indigo', 'R&D'),
#  ('Elmo Mooney', 186, 'yellow', 'R&D'),
#  ('Elmo Mooney', 186, 'red', 'R&D'),
#  ('Elmo Mooney', 186, 'indigo', 'R&D'),
#  ('Elmo Mooney', 186, 'red', 'R&D'),
#  ('Ferris Lindsey', 191, 'indigo', 'R&D'),
#  ('Ferris Lindsey', 191, 'red', 'R&D'),
#  ('Ferris Lindsey', 191, 'yellow', 'R&D'),
#  ('Ferris Lindsey', 191, 'red', 'R&D'),
#  ('Giacomo Douglas', 196, 'red', 'R&D'),
#  ('Giacomo Douglas', 196, 'indigo', 'R&D'),
#  ('Giacomo Douglas', 196, 'yellow', 'R&D'),
#  ('Giacomo Douglas', 196, 'red', 'R&D'),
#  ('Henry Lane', 147, 'yellow', 'R&D'),
#  ('Henry Lane', 147, 'indigo', 'R&D'),
#  ('Henry Lane', 147, 'red', 'R&D'),
#  ('Henry Lane', 147, 'red', 'R&D'),
#  ('Ian Shepard', 198, 'indigo', 'R&D'),
#  ('Ian Shepard', 198, 'red', 'R&D'),
#  ('Ian Shepard', 198, 'red', 'R&D'),
#  ('Ian Shepard', 198, 'yellow', 'R&D'),
#  ('Joshua Fernandez', 149, 'red', 'R&D'),
#  ('Joshua Fernandez', 149, 'red', 'R&D'),
#  ('Joshua Fernandez', 149, 'indigo', 'R&D'),
#  ('Joshua Fernandez', 149, 'yellow', 'R&D'),
#  ('Kasimir Larsen', 108, 'indigo', 'R&D'),
#  ('Kasimir Larsen', 108, 'red', 'R&D'),
#  ('Kasimir Larsen', 108, 'red', 'R&D'),
#  ('Kasimir Larsen', 108, 'yellow', 'R&D'),
#  ('Kennan Sosa', 192, 'indigo', 'R&D'),
#  ('Kennan Sosa', 192, 'red', 'R&D'),
#  ('Kennan Sosa', 192, 'red', 'R&D'),
#  ('Kennan Sosa', 192, 'yellow', 'R&D'),
#  ('Kenneth Snyder', 176, 'red', 'R&D'),
#  ('Kenneth Snyder', 176, 'yellow', 'R&D'),
#  ('Kenneth Snyder', 176, 'red', 'R&D'),
#  ('Kenneth Snyder', 176, 'indigo', 'R&D'),
#  ('Leroy Buck', 182, 'indigo', 'R&D'),
#  ('Leroy Buck', 182, 'yellow', 'R&D'),
#  ('Leroy Buck', 182, 'red', 'R&D'),
#  ('Leroy Buck', 182, 'red', 'R&D'),
#  ('Marshall Rice', 163, 'indigo', 'R&D'),
#  ('Marshall Rice', 163, 'red', 'R&D'),
#  ('Marshall Rice', 163, 'yellow', 'R&D'),
#  ('Marshall Rice', 163, 'red', 'R&D'),
#  ('Odysseus Delgado', 115, 'yellow', 'R&D'),
#  ('Odysseus Delgado', 115, 'red', 'R&D'),
#  ('Odysseus Delgado', 115, 'red', 'R&D'),
#  ('Odysseus Delgado', 115, 'indigo', 'R&D'),
#  ('Phillip Tillman', 135, 'red', 'R&D'),
#  ('Phillip Tillman', 135, 'indigo', 'R&D'),
#  ('Phillip Tillman', 135, 'red', 'R&D'),
#  ('Phillip Tillman', 135, 'yellow', 'R&D'),
#  ('Richard Carrillo', 154, 'yellow', 'R&D'),
#  ('Richard Carrillo', 154, 'red', 'R&D'),
#  ('Richard Carrillo', 154, 'indigo', 'R&D'),
#  ('Richard Carrillo', 154, 'red', 'R&D'),
#  ('Timon Mcmahon', 113, 'red', 'R&D'),
#  ('Timon Mcmahon', 113, 'red', 'R&D'),
#  ('Timon Mcmahon', 113, 'yellow', 'R&D'),
#  ('Timon Mcmahon', 113, 'indigo', 'R&D'),
#  ('Chadwick Riggs', 199, 'yellow', 'Sales'),
#  ('Chadwick Riggs', 199, 'orange', 'Sales'),
#  ('Chancellor Edwards', 200, 'orange', 'Sales'),
#  ('Chancellor Edwards', 200, 'yellow', 'Sales'),
#  ('Conan Allison', 180, 'orange', 'Sales'),
#  ('Conan Allison', 180, 'yellow', 'Sales'),
#  ('Dane Medina', 148, 'orange', 'Sales'),
#  ('Dane Medina', 148, 'yellow', 'Sales'),
#  ('Felix Frye', 124, 'yellow', 'Sales'),
#  ('Felix Frye', 124, 'orange', 'Sales'),
#  ('Gregory Morin', 121, 'orange', 'Sales'),
#  ('Gregory Morin', 121, 'yellow', 'Sales'),
#  ('Howard Shepard', 138, 'yellow', 'Sales'),
#  ('Howard Shepard', 138, 'orange', 'Sales'),
#  ('Nicholas Daugherty', 137, 'orange', 'Sales'),
#  ('Nicholas Daugherty', 137, 'yellow', 'Sales'),
#  ('Price Chavez', 144, 'orange', 'Sales'),
#  ('Price Chavez', 144, 'yellow', 'Sales'),
#  ('Rudyard Hendrix', 171, 'yellow', 'Sales'),
#  ('Rudyard Hendrix', 171, 'orange', 'Sales'),
#  ('Tiger Dennis', 162, 'orange', 'Sales'),
#  ('Tiger Dennis', 162, 'yellow', 'Sales'),
#  ('Vernon Randolph', 105, 'yellow', 'Sales'),
#  ('Vernon Randolph', 105, 'orange', 'Sales'),
#  ('Walker Wiggins', 168, 'yellow', 'Sales'),
#  ('Walker Wiggins', 168, 'orange', 'Sales'),
#  ('William Dejesus', 134, 'orange', 'Sales'),
#  ('William Dejesus', 134, 'yellow', 'Sales'),
#  ('Wyatt House', 141, 'orange', 'Sales'),
#  ('Wyatt House', 141, 'yellow', 'Sales'),
#  ('Wyatt Vance', 175, 'orange', 'Sales'),
#  ('Wyatt Vance', 175, 'yellow', 'Sales'),
#  ('Xanthus Holman', 143, 'yellow', 'Sales'),
#  ('Xanthus Holman', 143, 'orange', 'Sales'),
#  ('Xanthus Ortega', 157, 'yellow', 'Sales'),
#  ('Xanthus Ortega', 157, 'orange', 'Sales')]

# %% [markdown]
# ### 12. For each project on which more than two employees work, retrieve the project number, the project name, and the number of employees who work on the project.

# %%
# %%sql
# SELECT Project, COUNT(Employee)
# FROM WorksOn AS w, Employees AS e
# WHERE e.SSN = w.Employee
# GROUP BY Project
# HAVING COUNT(*) > 2;
# Out:
#  * postgresql://piyush2017:***@127.0.0.1/interviews
# 18 rows affected.
# [(8, 3),
#  (19, 4),
#  (4, 6),
#  (14, 6),
#  (3, 5),
#  (17, 6),
#  (20, 4),
#  (10, 4),
#  (7, 6),
#  (13, 6),
#  (1, 5),
#  (5, 7),
#  (18, 4),
#  (2, 3),
#  (15, 7),
#  (16, 3),
#  (6, 8),
#  (12, 10)]

# %% [markdown]
# ### 13. For each project, retrieve the project number, the project name and the number of employees from department 10 (in my sample data we don't have department 10 so we look for department 3) who work on the project.

# %%
# %%sql
#
# SELECT p.PNumber, p.PName, Count(*)
# FROM Projects AS p, WorksOn AS w, Employees AS e
# WHERE p.PNumber = w.Project
# AND w.Employee = e.SSN
# AND e.AssignedTo = 3
# GROUP BY p.PNumber;
# Out:
#  * postgresql://piyush2017:***@127.0.0.1/interviews
# 13 rows affected.
# [(19, 'red', 1),
#  (4, 'indigo', 1),
#  (14, 'yellow', 1),
#  (17, 'yellow', 1),
#  (20, 'indigo', 1),
#  (13, 'orange', 1),
#  (10, 'violet', 2),
#  (7, 'red', 2),
#  (1, 'red', 2),
#  (15, 'orange', 1),
#  (16, 'yellow', 1),
#  (6, 'violet', 1),
#  (12, 'red', 1)]

# %% [markdown]
# ### 14. Retrieve the names of employees who have all dependants with their same sex.

# %%
# %%sql
# SELECT e.Name
# FROM Employees AS e, Dependents AS d
# WHERE e.SSN = d.HouseHolder
# AND EXISTS (
#         SELECT *
#         FROM Dependents AS f
#         WHERE e.SSN = f.HouseHolder
#         AND f.Sex = e.Sex)
# GROUP BY e.Name, e.SSN
# HAVING COUNT(DISTINCT d.Sex) = 1;
# Out:
#  * postgresql://piyush2017:***@127.0.0.1/interviews
# 33 rows affected.
# [('Calvin Anthony',),
#  ('Mufutau Mitchell',),
#  ('Lawrence Cote',),
#  ('Buckminster Estrada',),
#  ('Gregory Morin',),
#  ('Troy Chandler',),
#  ('Hakeem Ferrell',),
#  ('Paki Phillips',),
#  ('Shad Whitfield',),
#  ('Phillip Tillman',),
#  ('Nicholas Daugherty',),
#  ('Jackson Sellers',),
#  ('Wyatt House',),
#  ('Xanthus Holman',),
#  ('Tate Hopper',),
#  ('Henry Lane',),
#  ('Joshua Fernandez',),
#  ('Wade Berger',),
#  ('Marvin Harrell',),
#  ('Cain Johnston',),
#  ('Joshua Craig',),
#  ('Walker Wiggins',),
#  ('Rudyard Hendrix',),
#  ('Ali Robinson',),
#  ('Kenneth Snyder',),
#  ('Jerry Donovan',),
#  ('Hop White',),
#  ('Conan Allison',),
#  ('Hashim Mcclure',),
#  ('Leo Austin',),
#  ('Chase Battle',),
#  ('Ferris Lindsey',),
#  ('Chadwick Riggs',)]

# %% [markdown]
# ### 15. Retrieve only the names of employees who have all dependants with the same sex. Let us write the query using universal quantification:

# %% [markdown]
# ### 16. Retrieve the names of employees who only work on project for 20 percent time.

# %% [markdown]
# ### 17. Retrieve the name of each employee who works at least on all the project to which employee 100 participates.

# %% [markdown]
# # all the avaliable tables
#
# Departments(Number, Name, Location)
#
# Employees (SSN,Name,Sex,BirthYear,AssignedTo)
#
# Dependents (HouseHolder,Name,Sex,BirthYear,Relationship)
#
# Supervisors (SSN,StartYear)
#
# Subordinates (SSN,SupervisedBy)
#
# Managers (SSN,Directs,StartYear)
#
# Projects (PNumber,PName,ManagedBy)
#
# WorksOn (Employee,Project,TimeShare)
#
# ## views we have
#
# DataSupervisors(SSN, Name, BirthYear, Sex, AssignedTo, StartYear)
#
# DataManagers (SSN, Name, BirthYear, Sex, AssignedTo, StartYear, Directs)
#
# DataSubordinates (SSN, Name, BirthYear, Sex, AssignedTo,SupervisedBy)
